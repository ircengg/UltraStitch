# %%
import os
import csv
import glob
import random
import string
import numpy as np
import pandas as pd
from io import StringIO

# -------------------------------------------------
# CONFIG
# -------------------------------------------------
folder_path = r"D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV"
output_folder = os.path.join(folder_path, "Ultrastitch")
os.makedirs(output_folder, exist_ok=True)

PROBE_PITCH_MM = 50  # 🔴 Probe spacing

# -------------------------------------------------
# SMALL RANDOM ID MAKER
# -------------------------------------------------
def make_small_id():
    return "S#" + ''.join(random.choices(string.ascii_uppercase, k=5))

all_properties = []

# -------------------------------------------------
# LOAD ANY SCAN AS CSV TEXT
# -------------------------------------------------
def load_scan_as_csv_text(filepath):
    ext = os.path.splitext(filepath)[1].lower()
    metadata = {}

    # -----------------------
    # TXT
    # -----------------------
    if ext == ".txt":
        matrix_lines = []

        with open(filepath, "r") as f:
            for line in f:
                line = line.strip()

                if line.startswith("mm"):
                    matrix_lines.append(line)
                    break

                if "=" in line:
                    k, v = [x.strip() for x in line.split("=", 1)]
                    metadata[k] = v

            for line in f:
                matrix_lines.append(line.strip())

        return "\n".join(matrix_lines), metadata

    # -----------------------
    # CSV
    # -----------------------
    if ext == ".csv":
        with open(filepath, "r") as f:
            return f.read(), metadata

    # -----------------------
    # EXCEL (Data sheet)
    # -----------------------
    if ext in [".xls", ".xlsx"]:
        df = pd.read_excel(filepath, sheet_name="Data", header=0)

        # Convert headers: P-1 → 0, P-2 → 50 ...
        new_cols = []
        for i, col in enumerate(df.columns):
            if i == 0:
                new_cols.append("mm")
            else:
                new_cols.append((i - 1) * PROBE_PITCH_MM)

        df.columns = new_cols

        buffer = StringIO()
        df.to_csv(buffer, index=False)
        return buffer.getvalue(), metadata

    raise ValueError(f"Unsupported file type: {filepath}")

# -------------------------------------------------
# PROCESS SCAN FILES
# -------------------------------------------------
scan_files = glob.glob(os.path.join(folder_path, "*.*"))

for scan_file in scan_files:
    if not scan_file.lower().endswith((".txt", ".csv", ".xls", ".xlsx")):
        continue

    print(f"Processing scan file: {scan_file}")

    properties = {
        "id": make_small_id(),
        "scan_details": os.path.basename(scan_file),
        "nominal_thk": None,
        "min_thk": None,
        "max_thk": None,
        "x": 0,
        "y": 0,
        "width": None,
        "height": None,
        "rotation": 0
    }

    # -----------------------
    # LOAD FILE AS CSV TEXT
    # -----------------------
    try:
        matrix_text, metadata = load_scan_as_csv_text(scan_file)
    except Exception as e:
        print(f"❌ Failed to load {scan_file}: {e}")
        continue

    # -----------------------
    # NUMPY PARSE
    # -----------------------
    data = np.genfromtxt(
        StringIO(matrix_text),
        delimiter=",",
        dtype=float,
        filling_values=np.nan
    )

    if data.ndim != 2 or data.shape[0] < 2 or data.shape[1] < 2:
        print(f"❌ Invalid matrix in file: {scan_file}")
        continue

    # -----------------------
    # AXES + MATRIX
    # -----------------------
    raw_x = data[0, 1:]

    # If headers were P-1, P-2 etc → NaN
    if np.isnan(raw_x).all():
        x_values = np.arange(data.shape[1] - 1) * PROBE_PITCH_MM
    else:
        x_values = raw_x

    y_values = data[1:, 0]
    t_values = data[1:, 1:]

    # -----------------------
    # REVERSE Y AXIS
    # -----------------------
    y_values = y_values[::-1]
    t_values = t_values[::-1, :]

    # -----------------------
    # GEOMETRY
    # -----------------------
    properties["width"] = float(np.nanmax(x_values) - np.nanmin(x_values))
    properties["height"] = float(np.nanmax(y_values) - np.nanmin(y_values))

    # -----------------------
    # THICKNESS STATS
    # -----------------------
    properties["min_thk"] = float(np.nanmin(t_values))
    properties["max_thk"] = float(np.nanmax(t_values))
    properties["nominal_thk"] = float(metadata.get("Max Thickness (mm)", 0))

    # -----------------------
    # SAVE MATRIX CSV
    # -----------------------
    csv_filename = properties["id"] + ".csv"
    csv_filepath = os.path.join(output_folder, csv_filename)

    with open(csv_filepath, "w", newline="") as csvfile:
        writer = csv.writer(csvfile)

        writer.writerow(["mm"] + list(x_values))

        for y, row in zip(y_values, t_values):
            writer.writerow([y] + row.tolist())

    all_properties.append(properties)

# -------------------------------------------------
# SAVE MASTER PROPERTIES CSV
# -------------------------------------------------
properties_csv = os.path.join(output_folder, "scan_properties.csv")

if all_properties:
    with open(properties_csv, "w", newline="") as csvfile:
        writer = csv.writer(csvfile)
        header = list(all_properties[0].keys())
        writer.writerow(header)
        for p in all_properties:
            writer.writerow([p[h] for h in header])

    print(f"\n✅ Saved all properties → {properties_csv}")
else:
    print("\n⚠ No valid scan files found.")
# Out:
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-100-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-101-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-102-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-103-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-104-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-105-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-106-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-107-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-108-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-109-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-110-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-111-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-112-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-113-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-114-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-115-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-116-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-117-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-118-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-119-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-120-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-121-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-122-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-123-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-124-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-125-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-126-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-127-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-128-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-129-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-130-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-131-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-132-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-133-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-135-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-136-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-137-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-138-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-139-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-140-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-141-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-142-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-143-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-144-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-146-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-147-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-148-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-149-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-150-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-151-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-152-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-153-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-154-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-155-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-156-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-157-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-158-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-159-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-160-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-161-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-162-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-163-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-164-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-165-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-166-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-167-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-168-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-169-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-17-(N-25)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-170-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-171-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-172-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-173-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-174-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-175-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-176-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-177-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-178-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-179-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-180-(N-32)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-181-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-182-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-183-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-184-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-185-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-187-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-188-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-189-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-19-(N-25)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-190-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-191-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-192-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-193-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-194-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-195-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-196-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-197-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-198-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-199-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-20-(N-25)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-200-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-201-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-202-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-203-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-204-(N-32)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-205-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-206-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-207-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-208-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-209-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-21-(N-25)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-210-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-211-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-212-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-213-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-214-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-22-(N-25)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-23-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-24-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-25-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-26-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-27-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-28-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-29-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-30-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-31-(N-35)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-32-(N-25)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-33-(N-25)FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-34-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-36-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-37-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-40-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-41-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-42-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-43-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-44-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-46-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-48-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-49-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-51-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-52-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-53-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-54-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-55-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-57-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-58-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-59-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-61-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-63-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-64-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-65-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-67-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-68-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-70-(N-35)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-71-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-72-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-73-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-74-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-75-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-76-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-77-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-78-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-79-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-80-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-81-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-82-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-83-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-84-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-85-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-86-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-87-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-88-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-89-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-90-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-91-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-92-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-93-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-94-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-95-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-96-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-97-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-98-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan No-99-(N-25)FE.csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\scan-134-N-25-(FE).csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\scan-188-N-35-(FE).csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\scan-189-N-32-(FE).csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\scan-192-N-32-(FE).csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\scan-211-N-35-(FE).csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-38-N-25-(FE).csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-39-N-25-(FE).csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-45-N-25-(FE).csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-47-N-25-(FE).csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-50-N-25-(FE).csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-56-N-25-(FE).csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\scan-60-N-35-(FE).csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\scan-62-N-35-(FE).csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\scan-63-N-35-(FE).csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\scan-66-N-35-(FE).csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\scan-69-N-35-(FE).csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-89-N-25-(FE).csv
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-N0-01-(N-25)-FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-N0-02-(N-25)-FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-N0-03-(N-25)-FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-N0-04-(N-25)-FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-N0-05-(N-25)-FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-N0-06-(N-25)-FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-N0-07-(N-25)-FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-N0-08-(N-25)-FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-N0-09-(N-25)-FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-N0-10-(N-25)-FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-N0-11-(N-25)-FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-N0-12-(N-25)-FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-N0-13-(N-25)-FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-N0-14-(N-25)-FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-N0-15-(N-25)-FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-N0-16-(N-25)-FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-N0-18-(N-25)-FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Scan-N0-203-(N-35)-FE.xlsx
# Processing scan file: D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\~$Scan No-21-(N-25)FE.xlsx
# ❌ Failed to load D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\~$Scan No-21-(N-25)FE.xlsx: Excel file format cannot be determined, you must specify an engine manually.
#
# ✅ Saved all properties → D:\Tpac Workdir\Ultratech Kiln\Tadipatri\CSV\Ultrastitch\scan_properties.csv
